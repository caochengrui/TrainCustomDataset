# %% [markdown]
# # Load Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# make sure the runtime type is GPU
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/CustomDataset.zip", 'r')
zip_ref.extractall("/content/dataset")
zip_ref.close()

# %%
import os
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator

def load_dataset(data_dir='/content/dataset/CustomDataset', image_size=(32, 32), batch_size=32):
    # Create an instance of ImageDataGenerator with pixel values scaled to [0, 1]
    datagen = ImageDataGenerator(rescale=1/255)

    train_generator = datagen.flow_from_directory(
        os.path.join(data_dir, 'train'),
        # Resize all images to this size
        target_size=image_size,
        batch_size=batch_size,
        # Use one-hot encoded labels
        class_mode='categorical'
    )

    test_generator = datagen.flow_from_directory(
        os.path.join(data_dir, 'test'),
        # Resize all images to this size
        target_size=image_size,
        batch_size=batch_size,
        # Use one-hot encoded labels
        class_mode='categorical'
    )

    # Fetch the first batch of train data (images and labels) from the generator
    train_images, train_labels = next(train_generator)
    # Fetch the first batch of test data (images and labels) from the generator
    test_images, test_labels = next(test_generator)

    # Keep fetching batches of train data until all samples are loaded
    while len(train_images) < train_generator.samples:
        batch_images, batch_labels = next(train_generator)
        # Concatenate the new batch with the already loaded test data
        train_images = np.concatenate([train_images, batch_images], axis=0)
        train_labels = np.concatenate([train_labels, batch_labels], axis=0)

    # Keep fetching batches of test data until all samples are loaded
    while len(test_images) < test_generator.samples:
        batch_images, batch_labels = next(test_generator)
        # Concatenate the new batch with the already loaded test data
        test_images = np.concatenate([test_images, batch_images], axis=0)
        test_labels = np.concatenate([test_labels, batch_labels], axis=0)

    return train_images, train_labels, test_images, test_labels


train_images, train_labels, test_images, test_labels = load_dataset()

print("Train images shape:", train_images.shape)
print("Train labels shape:", train_labels.shape)
print("Test images shape:", test_images.shape)
print("Test labels shape:", test_labels.shape)
# Out:
# Found 8804 images belonging to 3 classes.
# Found 3775 images belonging to 3 classes.
# Train images shape: (8804, 32, 32, 3)
# Train labels shape: (8804, 3)
# Test images shape: (3775, 32, 32, 3)
# Test labels shape: (3775, 3)

# %% [markdown]
# # Define Model Preparation

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD

def define_model():
  model = Sequential()
  model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3)))
  model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(MaxPooling2D(2, 2))
  # Dropout: avoid overfiting
  model.add(Dropout(0.2))
  model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(MaxPooling2D(2, 2))
  model.add(Dropout(0.2))
  model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(MaxPooling2D(2, 2))
  model.add(Dropout(0.2))
  model.add(Flatten())
  model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
  model.add(Dropout(0.2))
  # In this case, number of class is 3
  model.add(Dense(3, activation='softmax'))
  # compile model
  opt = SGD(learning_rate=0.001, momentum=0.9)
  model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
  return model

model = define_model()

# %% [markdown]
# # Train Model

# %%
history = model.fit(train_images, train_labels, epochs=100, batch_size=32, validation_data=(test_images, test_labels), verbose = 1, shuffle=True)
# Out:
# Epoch 1/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 14s 23ms/step - accuracy: 0.5295 - loss: 0.9874 - val_accuracy: 0.7060 - val_loss: 0.6027
# Epoch 2/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7548 - loss: 0.5562 - val_accuracy: 0.7764 - val_loss: 0.4862
# Epoch 3/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8037 - loss: 0.4614 - val_accuracy: 0.8763 - val_loss: 0.3440
# Epoch 4/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8279 - loss: 0.4078 - val_accuracy: 0.8318 - val_loss: 0.3875
# Epoch 5/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8622 - loss: 0.3441 - val_accuracy: 0.8842 - val_loss: 0.2889
# Epoch 6/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8814 - loss: 0.3119 - val_accuracy: 0.8562 - val_loss: 0.3561
# Epoch 7/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8865 - loss: 0.2933 - val_accuracy: 0.8283 - val_loss: 0.4142
# Epoch 8/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8887 - loss: 0.2836 - val_accuracy: 0.8029 - val_loss: 0.4728
# Epoch 9/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8955 - loss: 0.2788 - val_accuracy: 0.8517 - val_loss: 0.3651
# Epoch 10/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9029 - loss: 0.2501 - val_accuracy: 0.9128 - val_loss: 0.2505
# Epoch 11/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8992 - loss: 0.2531 - val_accuracy: 0.8426 - val_loss: 0.3869
# Epoch 12/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9101 - loss: 0.2393 - val_accuracy: 0.8909 - val_loss: 0.2650
# Epoch 13/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9118 - loss: 0.2250 - val_accuracy: 0.8890 - val_loss: 0.2799
# Epoch 14/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9146 - loss: 0.2200 - val_accuracy: 0.8840 - val_loss: 0.2786
# Epoch 15/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9198 - loss: 0.2257 - val_accuracy: 0.8996 - val_loss: 0.2532
# Epoch 16/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9216 - loss: 0.2056 - val_accuracy: 0.8477 - val_loss: 0.3766
# Epoch 17/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9192 - loss: 0.2077 - val_accuracy: 0.9028 - val_loss: 0.2398
# Epoch 18/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9313 - loss: 0.1832 - val_accuracy: 0.9038 - val_loss: 0.2326
# Epoch 19/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9258 - loss: 0.1935 - val_accuracy: 0.9327 - val_loss: 0.1848
# Epoch 20/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9342 - loss: 0.1774 - val_accuracy: 0.9147 - val_loss: 0.2162
# Epoch 21/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9409 - loss: 0.1640 - val_accuracy: 0.9377 - val_loss: 0.1751
# Epoch 22/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9385 - loss: 0.1617 - val_accuracy: 0.8726 - val_loss: 0.3137
# Epoch 23/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9418 - loss: 0.1507 - val_accuracy: 0.9240 - val_loss: 0.1922
# Epoch 24/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9413 - loss: 0.1562 - val_accuracy: 0.8641 - val_loss: 0.3270
# Epoch 25/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9430 - loss: 0.1503 - val_accuracy: 0.9152 - val_loss: 0.2116
# Epoch 26/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9444 - loss: 0.1492 - val_accuracy: 0.9362 - val_loss: 0.1681
# Epoch 27/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9451 - loss: 0.1449 - val_accuracy: 0.9253 - val_loss: 0.1857
# Epoch 28/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9412 - loss: 0.1515 - val_accuracy: 0.9502 - val_loss: 0.1470
# Epoch 29/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9489 - loss: 0.1374 - val_accuracy: 0.8903 - val_loss: 0.2717
# Epoch 30/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9472 - loss: 0.1424 - val_accuracy: 0.9192 - val_loss: 0.1955
# Epoch 31/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9512 - loss: 0.1361 - val_accuracy: 0.9250 - val_loss: 0.1891
# Epoch 32/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9563 - loss: 0.1184 - val_accuracy: 0.9174 - val_loss: 0.2132
# Epoch 33/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9424 - loss: 0.1480 - val_accuracy: 0.8930 - val_loss: 0.2816
# Epoch 34/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9384 - loss: 0.1486 - val_accuracy: 0.9240 - val_loss: 0.1873
# Epoch 35/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9534 - loss: 0.1220 - val_accuracy: 0.9407 - val_loss: 0.1563
# Epoch 36/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9540 - loss: 0.1189 - val_accuracy: 0.9290 - val_loss: 0.1830
# Epoch 37/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9591 - loss: 0.1070 - val_accuracy: 0.9412 - val_loss: 0.1520
# Epoch 38/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9602 - loss: 0.1103 - val_accuracy: 0.8948 - val_loss: 0.2614
# Epoch 39/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9574 - loss: 0.1112 - val_accuracy: 0.9423 - val_loss: 0.1516
# Epoch 40/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9609 - loss: 0.1078 - val_accuracy: 0.9099 - val_loss: 0.2170
# Epoch 41/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9631 - loss: 0.0982 - val_accuracy: 0.9139 - val_loss: 0.2084
# Epoch 42/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9635 - loss: 0.1015 - val_accuracy: 0.9393 - val_loss: 0.1575
# Epoch 43/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9674 - loss: 0.0850 - val_accuracy: 0.9401 - val_loss: 0.1488
# Epoch 44/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9666 - loss: 0.0888 - val_accuracy: 0.9475 - val_loss: 0.1414
# Epoch 45/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9660 - loss: 0.0866 - val_accuracy: 0.8887 - val_loss: 0.3124
# Epoch 46/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9611 - loss: 0.1019 - val_accuracy: 0.9290 - val_loss: 0.1858
# Epoch 47/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9710 - loss: 0.0836 - val_accuracy: 0.9436 - val_loss: 0.1521
# Epoch 48/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9657 - loss: 0.0898 - val_accuracy: 0.9558 - val_loss: 0.1252
# Epoch 49/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9681 - loss: 0.0835 - val_accuracy: 0.9502 - val_loss: 0.1413
# Epoch 50/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9682 - loss: 0.0830 - val_accuracy: 0.9460 - val_loss: 0.1500
# Epoch 51/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9713 - loss: 0.0767 - val_accuracy: 0.9221 - val_loss: 0.2155
# Epoch 52/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9663 - loss: 0.0857 - val_accuracy: 0.9407 - val_loss: 0.1625
# Epoch 53/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9708 - loss: 0.0768 - val_accuracy: 0.9391 - val_loss: 0.1716
# Epoch 54/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9702 - loss: 0.0772 - val_accuracy: 0.9563 - val_loss: 0.1203
# Epoch 55/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9724 - loss: 0.0767 - val_accuracy: 0.9563 - val_loss: 0.1209
# Epoch 56/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9709 - loss: 0.0781 - val_accuracy: 0.9544 - val_loss: 0.1224
# Epoch 57/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9682 - loss: 0.0832 - val_accuracy: 0.9560 - val_loss: 0.1219
# Epoch 58/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9742 - loss: 0.0644 - val_accuracy: 0.9478 - val_loss: 0.1408
# Epoch 59/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9732 - loss: 0.0719 - val_accuracy: 0.9377 - val_loss: 0.1687
# Epoch 60/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9761 - loss: 0.0624 - val_accuracy: 0.9385 - val_loss: 0.1729
# Epoch 61/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9710 - loss: 0.0756 - val_accuracy: 0.9388 - val_loss: 0.1481
# Epoch 62/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9771 - loss: 0.0624 - val_accuracy: 0.9531 - val_loss: 0.1339
# Epoch 63/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9774 - loss: 0.0646 - val_accuracy: 0.9348 - val_loss: 0.1876
# Epoch 64/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9812 - loss: 0.0530 - val_accuracy: 0.9428 - val_loss: 0.1559
# Epoch 65/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9758 - loss: 0.0639 - val_accuracy: 0.8861 - val_loss: 0.3768
# Epoch 66/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9755 - loss: 0.0715 - val_accuracy: 0.9364 - val_loss: 0.1818
# Epoch 67/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9789 - loss: 0.0595 - val_accuracy: 0.9499 - val_loss: 0.1236
# Epoch 68/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9774 - loss: 0.0601 - val_accuracy: 0.9460 - val_loss: 0.1481
# Epoch 69/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9803 - loss: 0.0544 - val_accuracy: 0.9526 - val_loss: 0.1367
# Epoch 70/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9794 - loss: 0.0550 - val_accuracy: 0.9423 - val_loss: 0.1717
# Epoch 71/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9814 - loss: 0.0466 - val_accuracy: 0.9566 - val_loss: 0.1366
# Epoch 72/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9799 - loss: 0.0560 - val_accuracy: 0.9452 - val_loss: 0.1506
# Epoch 73/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9851 - loss: 0.0418 - val_accuracy: 0.9539 - val_loss: 0.1241
# Epoch 74/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9809 - loss: 0.0473 - val_accuracy: 0.9385 - val_loss: 0.1821
# Epoch 75/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9838 - loss: 0.0443 - val_accuracy: 0.9407 - val_loss: 0.1801
# Epoch 76/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9854 - loss: 0.0412 - val_accuracy: 0.9613 - val_loss: 0.1294
# Epoch 77/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9752 - loss: 0.0773 - val_accuracy: 0.9367 - val_loss: 0.2095
# Epoch 78/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9827 - loss: 0.0474 - val_accuracy: 0.9595 - val_loss: 0.1071
# Epoch 79/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9874 - loss: 0.0360 - val_accuracy: 0.9436 - val_loss: 0.1607
# Epoch 80/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9893 - loss: 0.0327 - val_accuracy: 0.9502 - val_loss: 0.1536
# Epoch 81/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9905 - loss: 0.0292 - val_accuracy: 0.9385 - val_loss: 0.2018
# Epoch 82/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9807 - loss: 0.0512 - val_accuracy: 0.9470 - val_loss: 0.1705
# Epoch 83/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9867 - loss: 0.0370 - val_accuracy: 0.9457 - val_loss: 0.1639
# Epoch 84/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9758 - loss: 0.0697 - val_accuracy: 0.9539 - val_loss: 0.1471
# Epoch 85/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9874 - loss: 0.0334 - val_accuracy: 0.9563 - val_loss: 0.1325
# Epoch 86/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9869 - loss: 0.0383 - val_accuracy: 0.9285 - val_loss: 0.2177
# Epoch 87/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9839 - loss: 0.0374 - val_accuracy: 0.9558 - val_loss: 0.1305
# Epoch 88/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9859 - loss: 0.0415 - val_accuracy: 0.9563 - val_loss: 0.1497
# Epoch 89/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9919 - loss: 0.0243 - val_accuracy: 0.9608 - val_loss: 0.1269
# Epoch 90/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9890 - loss: 0.0300 - val_accuracy: 0.9330 - val_loss: 0.2225
# Epoch 91/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9891 - loss: 0.0309 - val_accuracy: 0.9587 - val_loss: 0.1370
# Epoch 92/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9871 - loss: 0.0314 - val_accuracy: 0.9372 - val_loss: 0.1941
# Epoch 93/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9827 - loss: 0.0443 - val_accuracy: 0.9608 - val_loss: 0.1337
# Epoch 94/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9920 - loss: 0.0222 - val_accuracy: 0.9528 - val_loss: 0.1645
# Epoch 95/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9901 - loss: 0.0241 - val_accuracy: 0.9605 - val_loss: 0.1319
# Epoch 96/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9841 - loss: 0.0382 - val_accuracy: 0.9462 - val_loss: 0.1647
# Epoch 97/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9897 - loss: 0.0261 - val_accuracy: 0.9634 - val_loss: 0.1219
# Epoch 98/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9907 - loss: 0.0258 - val_accuracy: 0.9629 - val_loss: 0.1364
# Epoch 99/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9931 - loss: 0.0210 - val_accuracy: 0.9475 - val_loss: 0.1664
# Epoch 100/100
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9948 - loss: 0.0201 - val_accuracy: 0.9457 - val_loss: 0.2002

# %% [markdown]
# # Evaluate Model

# %%
def evaluate_model():
  _, accuracy = model.evaluate(test_images, test_labels, verbose=0)
  print('> %.3f' % (accuracy * 100.0))

evaluate_model()
# Out:
# > 94.570

# %% [markdown]
# # Present Results

# %%
import matplotlib.pyplot as plt
import sys

def summarize_diagnostics(history):
	# plot loss
	plt.subplot(211)
	plt.title('Cross Entropy Loss')
	plt.plot(history.history['loss'], color='blue', label='train')
	plt.plot(history.history['val_loss'], color='orange', label='test')
	# plot accuracy
	plt.subplot(212)
	plt.title('Classification Accuracy')
	plt.plot(history.history['accuracy'], color='blue', label='train')
	plt.plot(history.history['val_accuracy'], color='orange', label='test')
	# save plot to file
	filename = sys.argv[0].split('/')[-1]
	plt.savefig(filename + '_plot.png')
	plt.close()

summarize_diagnostics(history)
